# %%
from lxml import html  
import requests
from requests.packages.urllib3.exceptions import InsecureRequestWarning
requests.packages.urllib3.disable_warnings(InsecureRequestWarning)
from dateutil import parser as dateparser
from time import sleep
import sys
import codecs
import nltk

# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/Ruta Lad/Desktop/Review.csv")

# %%
df
# Out:
#                                                  reviews
# 0      I order 3 of them and one of the item is bad q...
# 1      Bulk is always the less expensive way to go fo...
# 2      Well they are not Duracell but for the price i...
# 3      Seem to work as well as name brand batteries a...
# 4      These batteries are very long lasting the pric...
# 5      Bought a lot of batteries for Christmas and th...
# 6      ive not had any problame with these batteries ...
# 7      Well if you are looking for cheap non-recharge...
# 8      These do not hold the amount of high power jui...
# 9      AmazonBasics AA AAA batteries have done well b...
# 10     I find amazon basics batteries to be equal if ...
# 11     When I first started getting the Amazon basic ...
# 12     Use it for my fish tank's light at night and w...
# 13     just got em so I can't really comment on how g...
# 14     we have many things that need aa battery they ...
# 15     Thankful that I was able to find on Amazon for...
# 16     I don't know if I would buy thus brand again s...
# 17     In my opinion these did not last anywhere near...
# 18     They don't last as long as the brand name but ...
# 19     Bought these batteries for my Christmas gifts ...
# 20     This my second order and they seem to work as ...
# 21     This was my second purchase of amazon batterie...
# 22     They last as long as Duracell batteries in my ...
# 23     they seemed to not last as long as other name ...
# 24     These do not last long at all very cheap batte...
# 25     have not used yet but a battery is a battery g...
# 26     These Amazon batteries did the job although I ...
# 27     We've ordered these a few times cause we've be...
# 28     HAVE NOT HAD CHANCE TO USE ALL OF THEM BUT HOP...
# 29     these were under a light we thought they were ...
# ...                                                  ...
# 28302  Great product for the kids gaming apps parenta...
# 28303  I just like reading amd playing games on it..B...
# 28304  it would be nice to have full app library, but...
# 28305  Love the product. I use it every day for Web,G...
# 28306  Nicer than my old fire. Better screen area to ...
# 28307  Works great and is fast. Great for reading and...
# 28308  We use them for classes, they work great and a...
# 28309  So far so good with the kindle fire hd. still ...
# 28310  Simple to use. Great for Dad who wants to play...
# 28311  I wanted a tablet that was easy to use that I ...
# 28312  the tablet is great, but all the advertising i...
# 28313  make sure you buy a micro sd card with at leas...
# 28314  this works great if you use amazon a lot and w...
# 28315  Bought on Black Friday for my kids, my 3 year ...
# 28316  This fire is much better than the old one so f...
# 28317  the fire hd is great for reading kindle books ...
# 28318  The tablet works fine. It is responsive with g...
# 28319  The Parental Options need some work. You can't...
# 28320  Allows for reading of my Kindle lib and even p...
# 28321  I bought it for kindle books and was amazed by...
# 28322  this product is really awesome for kids to pla...
# 28323  The 8 In Fire tablet does everything my nexus ...
# 28324  Got this for my mom, so she could check facebo...
# 28325  its fast, it has good lighting. its got the 16...
# 28326  Where do I begin...good clarity, I love the si...
# 28327  I got 2 of these for my 8 yr old twins. My 11 ...
# 28328  I bought this for my niece for a Christmas gif...
# 28329  Very nice for light internet browsing, keeping...
# 28330  This Tablet does absolutely everything I want!...
# 28331  At ninety dollars, the expectionations are low...
#
# [28332 rows x 1 columns]

# %%
len(df)
# Out:
# 28332

# %%
#downloading nltk 
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
#downloading nltk 
import nltk
from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import sent_tokenize,word_tokenize
from nltk.stem import PorterStemmer

# %%
#tokenization and stopwords, steming
stop_word = set(stopwords.words("english"))
words = word_tokenize(str(df))
ps = PorterStemmer()
token_sents = sent_tokenize(str(df))

filtered_sent = []
for s in token_sents:
    filtered_sent.append(s)

filtered_am_reviews = []
for i in words:
    if i not in stop_word:
        filtered_am_reviews.append(ps.stem(i))

# %%
filtered_am_reviews
# Out:
# ['review',
#  '0',
#  'I',
#  'order',
#  '3',
#  'one',
#  'item',
#  'bad',
#  'q',
#  '...',
#  '1',
#  'bulk',
#  'alway',
#  'less',
#  'expens',
#  'way',
#  'go',
#  'fo',
#  '...',
#  '2',
#  'well',
#  'duracel',
#  'price',
#  '...',
#  '3',
#  'seem',
#  'work',
#  'well',
#  'name',
#  'brand',
#  'batteri',
#  '...',
#  '4',
#  'these',
#  'batteri',
#  'long',
#  'last',
#  'pric',
#  '...',
#  '5',
#  'bought',
#  'lot',
#  'batteri',
#  'christma',
#  'th',
#  '...',
#  '6',
#  'ive',
#  'problam',
#  'batteri',
#  '...',
#  '7',
#  'well',
#  'look',
#  'cheap',
#  'non-recharg',
#  '...',
#  '8',
#  'these',
#  'hold',
#  'amount',
#  'high',
#  'power',
#  'jui',
#  '...',
#  '9',
#  'amazonbas',
#  'AA',
#  'aaa',
#  'batteri',
#  'done',
#  'well',
#  'b',
#  '...',
#  '10',
#  'I',
#  'find',
#  'amazon',
#  'basic',
#  'batteri',
#  'equal',
#  '...',
#  '11',
#  'when',
#  'I',
#  'first',
#  'start',
#  'get',
#  'amazon',
#  'basic',
#  '...',
#  '12',
#  'use',
#  'fish',
#  'tank',
#  "'s",
#  'light',
#  'night',
#  'w',
#  '...',
#  '13',
#  'got',
#  'em',
#  'I',
#  'ca',
#  "n't",
#  'realli',
#  'comment',
#  'g',
#  '...',
#  '14',
#  'mani',
#  'thing',
#  'need',
#  'aa',
#  'batteri',
#  '...',
#  '15',
#  'thank',
#  'I',
#  'abl',
#  'find',
#  'amazon',
#  '...',
#  '16',
#  'I',
#  "n't",
#  'know',
#  'I',
#  'would',
#  'buy',
#  'thu',
#  'brand',
#  '...',
#  '17',
#  'In',
#  'opinion',
#  'last',
#  'anywher',
#  'near',
#  '...',
#  '18',
#  'they',
#  "n't",
#  'last',
#  'long',
#  'brand',
#  'name',
#  '...',
#  '19',
#  'bought',
#  'batteri',
#  'christma',
#  'gift',
#  '...',
#  '20',
#  'thi',
#  'second',
#  'order',
#  'seem',
#  'work',
#  '...',
#  '21',
#  'thi',
#  'second',
#  'purchas',
#  'amazon',
#  'batteri',
#  '...',
#  '22',
#  'they',
#  'last',
#  'long',
#  'duracel',
#  'batteri',
#  '...',
#  '23',
#  'seem',
#  'last',
#  'long',
#  'name',
#  '...',
#  '24',
#  'these',
#  'last',
#  'long',
#  'cheap',
#  'batt',
#  '...',
#  '25',
#  'use',
#  'yet',
#  'batteri',
#  'batteri',
#  'g',
#  '...',
#  '26',
#  'these',
#  'amazon',
#  'batteri',
#  'job',
#  'although',
#  'I',
#  '...',
#  '27',
#  'We',
#  "'ve",
#  'order',
#  'time',
#  'caus',
#  "'ve",
#  '...',
#  '28',
#  'have',
#  'not',
#  'had',
#  'chanc',
#  'TO',
#  'use',
#  'all',
#  'OF',
#  'them',
#  'but',
#  'hop',
#  '...',
#  '29',
#  'light',
#  'thought',
#  '...',
#  '...',
#  '...',
#  '28302',
#  'great',
#  'product',
#  'kid',
#  'game',
#  'app',
#  'parenta',
#  '...',
#  '28303',
#  'I',
#  'like',
#  'read',
#  'amd',
#  'play',
#  'game',
#  'it..b',
#  '...',
#  '28304',
#  'would',
#  'nice',
#  'full',
#  'app',
#  'librari',
#  ',',
#  '...',
#  '28305',
#  'love',
#  'product',
#  '.',
#  'I',
#  'use',
#  'everi',
#  'day',
#  'web',
#  ',',
#  'G',
#  '...',
#  '28306',
#  'nicer',
#  'old',
#  'fire',
#  '.',
#  'better',
#  'screen',
#  'area',
#  '...',
#  '28307',
#  'work',
#  'great',
#  'fast',
#  '.',
#  'great',
#  'read',
#  '...',
#  '28308',
#  'We',
#  'use',
#  'class',
#  ',',
#  'work',
#  'great',
#  '...',
#  '28309',
#  'So',
#  'far',
#  'good',
#  'kindl',
#  'fire',
#  'hd',
#  '.',
#  'still',
#  '...',
#  '28310',
#  'simpl',
#  'use',
#  '.',
#  'great',
#  'dad',
#  'want',
#  'play',
#  '...',
#  '28311',
#  'I',
#  'want',
#  'tablet',
#  'easi',
#  'use',
#  'I',
#  '...',
#  '28312',
#  'tablet',
#  'great',
#  ',',
#  'advertis',
#  '...',
#  '28313',
#  'make',
#  'sure',
#  'buy',
#  'micro',
#  'sd',
#  'card',
#  'lea',
#  '...',
#  '28314',
#  'work',
#  'great',
#  'use',
#  'amazon',
#  'lot',
#  'w',
#  '...',
#  '28315',
#  'bought',
#  'black',
#  'friday',
#  'kid',
#  ',',
#  '3',
#  'year',
#  '...',
#  '28316',
#  'thi',
#  'fire',
#  'much',
#  'better',
#  'old',
#  'one',
#  'f',
#  '...',
#  '28317',
#  'fire',
#  'hd',
#  'great',
#  'read',
#  'kindl',
#  'book',
#  '...',
#  '28318',
#  'the',
#  'tablet',
#  'work',
#  'fine',
#  '.',
#  'It',
#  'respons',
#  'g',
#  '...',
#  '28319',
#  'the',
#  'parent',
#  'option',
#  'need',
#  'work',
#  '.',
#  'you',
#  'ca',
#  "n't",
#  '...',
#  '28320',
#  'allow',
#  'read',
#  'kindl',
#  'lib',
#  'even',
#  'p',
#  '...',
#  '28321',
#  'I',
#  'bought',
#  'kindl',
#  'book',
#  'amaz',
#  '...',
#  '28322',
#  'product',
#  'realli',
#  'awesom',
#  'kid',
#  'pla',
#  '...',
#  '28323',
#  'the',
#  '8',
#  'In',
#  'fire',
#  'tablet',
#  'everyth',
#  'nexu',
#  '...',
#  '28324',
#  'got',
#  'mom',
#  ',',
#  'could',
#  'check',
#  'facebo',
#  '...',
#  '28325',
#  'fast',
#  ',',
#  'good',
#  'light',
#  '.',
#  'got',
#  '16',
#  '...',
#  '28326',
#  'where',
#  'I',
#  'begin',
#  '...',
#  'good',
#  'clariti',
#  ',',
#  'I',
#  'love',
#  'si',
#  '...',
#  '28327',
#  'I',
#  'got',
#  '2',
#  '8',
#  'yr',
#  'old',
#  'twin',
#  '.',
#  'My',
#  '11',
#  '...',
#  '28328',
#  'I',
#  'bought',
#  'niec',
#  'christma',
#  'gif',
#  '...',
#  '28329',
#  'veri',
#  'nice',
#  'light',
#  'internet',
#  'brows',
#  ',',
#  'keep',
#  '...',
#  '28330',
#  'thi',
#  'tablet',
#  'absolut',
#  'everyth',
#  'I',
#  'want',
#  '!',
#  '...',
#  '28331',
#  'At',
#  'nineti',
#  'dollar',
#  ',',
#  'expection',
#  'low',
#  '...',
#  '[',
#  '28332',
#  'row',
#  'x',
#  '1',
#  'column',
#  ']']

# %%
amazon_reviews =  pd.DataFrame(filtered_sent,columns=['Reviews'] )
amazon_reviews.head(500)
# Out:
#                                               Reviews
# 0                                                 ...
# 1   I use it every day for Web,G...\n28306  Nicer ...
# 2   Better screen area to ...\n28307  Works great ...
# 3   Great for reading and...\n28308  We use them f...
# 4                    still ...\n28310  Simple to use.
# 5   Great for Dad who wants to play...\n28311  I w...
# 6   It is responsive with g...\n28319  The Parenta...
# 7   You can't...\n28320  Allows for reading of my ...
# 8   its got the 16...\n28326  Where do I begin...g...
# 9   My 11 ...\n28328  I bought this for my niece f...
# 10  28331  At ninety dollars, the expectionations ...

# %%
x = amazon_reviews['Reviews']

# %%
x.head(20)
# Out:
# 0                                                   ...
# 1     I use it every day for Web,G...\n28306  Nicer ...
# 2     Better screen area to ...\n28307  Works great ...
# 3     Great for reading and...\n28308  We use them f...
# 4                      still ...\n28310  Simple to use.
# 5     Great for Dad who wants to play...\n28311  I w...
# 6     It is responsive with g...\n28319  The Parenta...
# 7     You can't...\n28320  Allows for reading of my ...
# 8     its got the 16...\n28326  Where do I begin...g...
# 9     My 11 ...\n28328  I bought this for my niece f...
# 10    28331  At ninety dollars, the expectionations ...
# Name: Reviews, dtype: object

# %%
x[1]
# Out:
# 'I use it every day for Web,G...\n28306  Nicer than my old fire.'

# %%
trans = CountVectorizer(words).fit(x)

# %%
len(trans.vocabulary_)
# Out:
# 281

# %%
review2 = x[1]

trans2 = trans.transform([review2])
print(trans2)
print(trans2.shape)
# Out:
#   (0, 23)	1
#   (0, 108)	1
#   (0, 120)	1
#   (0, 130)	1
#   (0, 134)	1
#   (0, 158)	1
#   (0, 188)	1
#   (0, 194)	1
#   (0, 201)	1
#   (0, 242)	1
#   (0, 257)	1
#   (0, 267)	1
# (1, 281)

# %%
print(trans.get_feature_names()[133])
print(trans.get_feature_names()[70])
# Out:
# fo
# apps

# %%
x = trans.transform(x)

# %%
x
# Out:
# <11x281 sparse matrix of type '<class 'numpy.int64'>'
# 	with 396 stored elements in Compressed Sparse Row format>

# %%
print('Shape of Sparse Matrix: ', x.shape)
print('Amount of Non-Zero occurences: ', x.nnz)
# Out:
# Shape of Sparse Matrix:  (11, 281)
# Amount of Non-Zero occurences:  396

# %%
den = (100.0 * x.nnz / (x.shape[0] * x.shape[1]))
print('density: {}'.format((den)))
# Out:
# density: 12.811387900355871

# %%
from textblob import TextBlob
import re

def senti_analyze(word):
    '''
    Utility function to classify the polarity of a tweet
    using textblob.
    '''
    analysis = TextBlob(word)
    if analysis.sentiment.polarity > 0:
        return 1
    elif analysis.sentiment.polarity == 0:
        return 0
    else:
        return -1

# %%
import numpy as np

# %%
amazon_reviews['Sentiment_Polarity'] = np.array([ senti_analyze(word) for word in amazon_reviews['Reviews'] ])

# %%
amazon_reviews.head(20)
# Out:
#                                               Reviews  Sentiment_Polarity
# 0                                                 ...                   1
# 1   I use it every day for Web,G...\n28306  Nicer ...                   1
# 2   Better screen area to ...\n28307  Works great ...                   1
# 3   Great for reading and...\n28308  We use them f...                   1
# 4                    still ...\n28310  Simple to use.                   0
# 5   Great for Dad who wants to play...\n28311  I w...                   1
# 6   It is responsive with g...\n28319  The Parenta...                   0
# 7   You can't...\n28320  Allows for reading of my ...                   1
# 8   its got the 16...\n28326  Where do I begin...g...                   1
# 9   My 11 ...\n28328  I bought this for my niece f...                   1
# 10  28331  At ninety dollars, the expectionations ...                   0

# %%
# Constructing lists with classified reviews:

positive_revs = [ review for index, review in enumerate(amazon_reviews['Reviews']) if amazon_reviews['Sentiment_Polarity'][index] > 0]
neutral_revs = [ review for index, review in enumerate(amazon_reviews['Reviews']) if amazon_reviews['Sentiment_Polarity'][index] == 0]
negative_revs = [ review for index, review in enumerate(amazon_reviews['Reviews']) if amazon_reviews['Sentiment_Polarity'][index] < 0]

# %%
# Printing percentages:

print("Percentage of positive reviews: {}%".format(len(positive_revs)*100/len(amazon_reviews['Reviews'])))
print("Percentage of neutral reviews: {}%".format(len(neutral_revs)*100/len(amazon_reviews['Reviews'])))
print("Percentage of negative reviews: {}%".format(len(negative_revs)*100/len(amazon_reviews['Reviews'])))
# Out:
# Percentage of positive reviews: 72.72727272727273%
# Percentage of neutral reviews: 27.272727272727273%
# Percentage of negative reviews: 0.0%

# %%
from sklearn.model_selection import train_test_split

# %%
y=amazon_reviews["Sentiment_Polarity"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()

# %%
nb.fit(x_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
prediction = nb.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score

# %%
print(confusion_matrix(y_test, prediction))
print('\n')
print(classification_report(y_test, prediction))
accuracy_score(y_test, prediction, normalize = True)
# Out:
# [[0 0]
#  [1 2]]
#
#
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         0
#           1       1.00      0.67      0.80         3
#
# avg / total       1.00      0.67      0.80         3
# C:\Users\Ruta Lad\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# 0.6666666666666666
